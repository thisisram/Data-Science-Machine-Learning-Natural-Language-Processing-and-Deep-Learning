# %%
import random
import numpy as np
import tensorflow.keras
#import wandb
#from wandb.keras import WandbCallback
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Flatten, Dense, Concatenate, Dot, Lambda, Input
from tensorflow.keras.datasets import mnist
from tensorflow.keras.optimizers import Adam, SGD
import matplotlib.pyplot as plt

from tensorflow.keras import applications

from tensorflow.keras.preprocessing import image
import os

import re

# %%
#http://vision.ucsd.edu/content/yale-face-database
img_dir = "../data/yalefaces/"
faceImages = os.listdir(img_dir)
print("Number of Cat images - ",str(len(faceImages)))
print(faceImages[1])

#img_path = 'elephant.jpg'
img = image.load_img(img_dir + faceImages[1], target_size=(224, 224))
x = image.img_to_array(img)

img
# Out:
# Number of Cat images -  166
# subject02.centerlight
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F85E9F18070>

# %%
x.shape
# Out:
# (224, 224, 3)

# %%
x_train = np.zeros((len(faceImages), 224, 224, 3))
y_train = np.empty((len(faceImages),), dtype=np.object_)
for i, face in enumerate(faceImages):
    img = image.load_img(img_dir + face, target_size=(224, 224))
    x = image.img_to_array(img)
    y = face[ : face.index('.')]
    x_train[i] = x
    y_train[i] = y
    
print(x_train.shape)
print(y_train.shape)
# Out:
# (166, 224, 224, 3)
# (166,)

# %%
y_train
# Out:
# array(['subject04', 'subject02', 'subject07', 'subject10', 'subject15',
#        'subject13', 'subject11', 'subject12', 'subject01', 'subject08',
#        'subject07', 'subject02', 'subject15', 'subject07', 'subject06',
#        'subject04', 'subject15', 'subject12', 'subject05', 'subject12',
#        'subject08', 'subject10', 'subject14', 'subject05', 'subject03',
#        'subject05', 'subject11', 'subject01', 'subject10', 'subject14',
#        'subject09', 'subject15', 'subject07', 'subject01', 'subject02',
#        'subject04', 'subject13', 'subject03', 'subject08', 'subject15',
#        'subject08', 'subject14', 'subject11', 'subject10', 'subject10',
#        'subject04', 'subject11', 'subject06', 'subject13', 'subject11',
#        'subject14', 'subject14', 'subject08', 'subject06', 'subject06',
#        'subject03', 'subject09', 'subject10', 'subject07', 'subject01',
#        'subject13', 'subject01', 'subject15', 'subject02', 'subject09',
#        'subject15', 'subject12', 'subject09', 'subject04', 'subject15',
#        'subject07', 'subject06', 'subject03', 'subject13', 'subject09',
#        'subject08', 'subject01', 'subject03', 'subject12', 'subject01',
#        'subject14', 'subject04', 'subject01', 'subject12', 'subject06',
#        'subject02', 'subject14', 'subject12', 'subject05', 'subject03',
#        'subject10', 'subject04', 'subject05', 'subject02', 'subject14',
#        'subject03', 'subject08', 'subject14', 'subject02', 'subject02',
#        'subject09', 'subject12', 'subject11', 'subject08', 'subject06',
#        'subject07', 'subject13', 'subject10', 'subject11', 'subject07',
#        'subject15', 'subject07', 'subject04', 'subject06', 'subject03',
#        'subject10', 'subject11', 'subject05', 'subject13', 'subject07',
#        'subject03', 'subject04', 'subject07', 'subject10', 'subject12',
#        'subject05', 'subject06', 'subject02', 'subject11', 'subject09',
#        'subject13', 'subject01', 'subject09', 'subject08', 'subject05',
#        'subject13', 'subject08', 'subject03', 'subject02', 'subject05',
#        'subject11', 'subject12', 'subject03', 'subject02', 'subject01',
#        'subject15', 'subject06', 'subject10', 'subject11', 'subject04',
#        'subject09', 'subject15', 'subject09', 'subject13', 'subject04',
#        'subject01', 'subject08', 'subject05', 'subject09', 'subject12',
#        'subject06', 'subject13', 'subject05', 'subject01', 'subject14',
#        'subject14'], dtype=object)

# %%
np.where(y_train == 'subject05')
# Out:
# (array([ 18,  23,  25,  88,  92, 117, 125, 134, 139, 157, 162]),)

# %%
y_train[8]
# Out:
# 'subject01'

# %%
np.unique(y_train)
# Out:
# array(['subject01', 'subject02', 'subject03', 'subject04', 'subject05',
#        'subject06', 'subject07', 'subject08', 'subject09', 'subject10',
#        'subject11', 'subject12', 'subject13', 'subject14', 'subject15'],
#       dtype=object)

# %%
random.choice([1,2,3,1,3,4,3,2,2,3,3,3])
# Out:
# 4

# %%
random.randint(0, 9)
# Out:
# 1

# %%
# make pairs
def make_pairs(x, y):
    classes = np.unique(y_train)
    num_classes = len(classes)
    
    face_indices_dict = {cls:np.where(y == cls)[0] for cls in classes}
    #print(face_indices_dict)
    #print(digit_indices)
    #print('len *****', len(digit_indices))
    #print('3 digit array', digit_indices[3])
    
    pairs = []
    labels = []

    for idx1 in range(len(x)):
        # add a matching example
        x1 = x[idx1]
        label1 = y[idx1]
        for _ in range(5):
            idx2 = random.choice(face_indices_dict[label1])
            x2 = x[idx2]
            pairs += [[x1, x2]]
            labels += [1]
    
        # add a not matching example
        other_labels = [cls for cls in classes if cls not in [label1]]
        
        label2 = random.choice(other_labels)

        for _ in range(5):
        #print(label1, ' --- ', label2)    
            idx2 = random.choice(face_indices_dict[label2])
            x2 = x[idx2]
            pairs += [[x1, x2]]
            labels += [0]

    return np.array(pairs), np.array(labels)

pairs_train, labels_train = make_pairs(x_train, y_train)
#pairs_test, labels_test = make_pairs(x_test, y_test)

# %%
x_train.shape
# Out:
# (166, 224, 224, 3)

# %%
pairs_train.shape
# Out:
# (1660, 2, 224, 224, 3)

# %%
labels_train.shape
# Out:
# (1660,)

# %%
pairs_train[0,0,:].shape
# Out:
# (224, 224, 3)

# %%
def showPic(pixels):
    image = pixels/np.amax(pixels)
    image = np.clip(image, 0, 1)
    plt.imshow(image)

# %%
# take a peek at the data
showPic(pairs_train[0,0,:])

# %%
showPic(pairs_train[0,1,:])

# %%
labels_train[0]
# Out:
# 1

# %%
showPic(pairs_train[119,0,:])

# %%
showPic(pairs_train[119,1,:])

# %%
labels_train[119]
# Out:
# 0

# %%
#!pip install tensorflow_addons

# %%
'''input_tensor = Input(shape=(224, 224, 3))
resnet_model = applications.ResNet50(weights='imagenet',
                               include_top=False,
                               input_tensor=input_tensor)

resnet_model.summary()'''
# Out:
# "input_tensor = Input(shape=(224, 224, 3))\nresnet_model = applications.ResNet50(weights='imagenet',\n                               include_top=False,\n                               input_tensor=input_tensor)\n\nresnet_model.summary()"

# %%
import tensorflow_addons as tfa

# %%
from tensorflow.keras import backend as K

def euclidean_distance(vects):
    x, y = vects
    sum_square = K.sum(K.square(x - y), axis=1, keepdims=True)
    return K.sqrt(K.maximum(sum_square, K.epsilon())) # sum_square come as zero 


input_tensor = Input(shape=(224, 224, 3))
resnet_model = applications.ResNet50(weights='imagenet',
                               include_top=False,
                               input_tensor=input_tensor)

# Creating dictionary that maps layer names to the layers
layer_dict = dict([(layer.name, layer) for layer in resnet_model.layers])
    
x = layer_dict['conv5_block3_out'].output
x = Flatten()(x)
x = Dense(256, activation=K.relu)(x)
x = Dense(128, activation=K.relu)(x)

face_encoder_model = Model(inputs=resnet_model.input, outputs=x)

lock_layer_count = len(layer_dict) + 1
print(lock_layer_count)
for layer in face_encoder_model.layers[ :lock_layer_count]:
    layer.trainable = False 


input_anchor_face = Input(shape=(224, 224, 3))
input_pos_or_neg_face = Input(shape=(224, 224, 3))

anchor_siamese_net = face_encoder_model(input_anchor_face)
pos_or_neg_siamese_net = face_encoder_model(input_pos_or_neg_face)

merge_layer = Lambda(euclidean_distance)([anchor_siamese_net, pos_or_neg_siamese_net])

sigmoid_layer = Dense(1, activation="sigmoid")(merge_layer)

model = Model(inputs=[input_anchor_face, input_pos_or_neg_face], outputs=sigmoid_layer)
# Out:
# 176

# %%
optimizer = SGD(learning_rate=0.000001)

model.compile(loss =tfa.losses.TripletSemiHardLoss(), optimizer=optimizer, metrics=["accuracy"])
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# model (Functional)              (None, 128)          49310976    input_2[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 1)            0           model[0][0]
#                                                                  model[1][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1)            2           lambda[0][0]
# ==================================================================================================
# Total params: 49,310,978
# Trainable params: 25,723,266
# Non-trainable params: 23,587,712
# __________________________________________________________________________________________________

# %%
pairs_train[:,0].shape
# Out:
# (1660, 224, 224, 3)

# %%
pairs_train[:,1].shape
# Out:
# (1660, 224, 224, 3)

# %%
model.fit([pairs_train[:,0], pairs_train[:,1]], labels_train[:], batch_size=8, epochs=30)
# Out:
# Epoch 1/30
# 208/208 [==============================] - 189s 876ms/step - loss: 1.0074 - accuracy: 0.5124
# Epoch 2/30
# 208/208 [==============================] - 197s 945ms/step - loss: 1.0111 - accuracy: 0.5002
# Epoch 3/30
# 208/208 [==============================] - 194s 934ms/step - loss: 1.0150 - accuracy: 0.5075
# Epoch 4/30
# 208/208 [==============================] - 198s 953ms/step - loss: 1.0186 - accuracy: 0.4918
# Epoch 5/30
# 208/208 [==============================] - 201s 968ms/step - loss: 1.0089 - accuracy: 0.4909
# Epoch 6/30
# 208/208 [==============================] - 201s 968ms/step - loss: 0.9934 - accuracy: 0.5005
# Epoch 7/30
# 208/208 [==============================] - 207s 993ms/step - loss: 1.0005 - accuracy: 0.4953
# Epoch 8/30
# 208/208 [==============================] - 216s 1s/step - loss: 1.0147 - accuracy: 0.5000
# Epoch 9/30
# 208/208 [==============================] - 219s 1s/step - loss: 1.0043 - accuracy: 0.5013
# Epoch 10/30
# 208/208 [==============================] - 220s 1s/step - loss: 1.0137 - accuracy: 0.5054
# Epoch 11/30
# 208/208 [==============================] - 219s 1s/step - loss: 1.0110 - accuracy: 0.5140
# Epoch 12/30
# 208/208 [==============================] - 216s 1s/step - loss: 1.0154 - accuracy: 0.4846
# Epoch 13/30
# 208/208 [==============================] - 215s 1s/step - loss: 1.0094 - accuracy: 0.5010
# Epoch 14/30
# 208/208 [==============================] - 212s 1s/step - loss: 1.0094 - accuracy: 0.4986
# Epoch 15/30
# 208/208 [==============================] - 221s 1s/step - loss: 1.0162 - accuracy: 0.5023
# Epoch 16/30
# 208/208 [==============================] - 220s 1s/step - loss: 1.0120 - accuracy: 0.5001
# Epoch 17/30
# 208/208 [==============================] - 190s 911ms/step - loss: 1.0109 - accuracy: 0.4982
# Epoch 18/30
# 208/208 [==============================] - 195s 936ms/step - loss: 1.0120 - accuracy: 0.4845
# Epoch 19/30
# 208/208 [==============================] - 179s 858ms/step - loss: 1.0108 - accuracy: 0.4904
# Epoch 20/30
# 208/208 [==============================] - 168s 808ms/step - loss: 1.0109 - accuracy: 0.4802
# Epoch 21/30
# 208/208 [==============================] - 165s 794ms/step - loss: 1.0148 - accuracy: 0.5053
# Epoch 22/30
# 208/208 [==============================] - 164s 790ms/step - loss: 1.0039 - accuracy: 0.4977
# Epoch 23/30
# 208/208 [==============================] - 164s 786ms/step - loss: 1.0071 - accuracy: 0.5078
# Epoch 24/30
# 208/208 [==============================] - 164s 787ms/step - loss: 1.0149 - accuracy: 0.5032
# Epoch 25/30
# 208/208 [==============================] - 3156s 15s/step - loss: 1.0029 - accuracy: 0.5201
# Epoch 26/30
# 142/208 [===================>..........] - ETA: 37s - loss: 1.0035 - accuracy: 0.5001

# %%
anchor_siamese_net = face_encoder_model(input_anchor_face)

# %% [markdown]
# Kaggle - Challenges in Representation Learning: Facial Expression Recognition Challenge
#   * https://www.kaggle.com/c/challenges-in-representation-learning-facial-expression-recognition-challenge/discussion
#   * https://www.youtube.com/watch?v=DtBu1u5aBsc

# %% [markdown]
# Sliding Window Classifier: Rain Drop Detection
#   * https://github.com/tobybreckon/raindrop-detection-cnn/blob/master/raindrop_detection_sliding_window.py

# %% [markdown]
# Convolutional implementation of the sliding window algorithm
#   * https://medium.com/ai-quest/convolutional-implementation-of-the-sliding-window-algorithm-db93a49f99a0
